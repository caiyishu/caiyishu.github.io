# %%
import base64, textwrap, pathlib
data = pathlib.Path("./PNG.png").read_bytes()
b64  = base64.b64encode(data).decode()
# 可选：每 76 字符换行，方便阅读
wrapped = "\n".join(textwrap.wrap(b64, 76))
print(f"data:image/png;base64,{wrapped}")
# Out:
# ...
